# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmay023/GREEN-SKILL-AND-AI/blob/main/day5_shell_india.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# > GLOBAL MINIMUN
# > LEARNING RATE = 0.001
# > WHY DO YOU GIVE SMALL LEARNING VALUE?
# > ADAPT
#
# >MAE DOES NOT AFFECT WITH OUTLIERS
# > SIGMOID ACTIVATION FUNCTION IN CLASSIFICATION ML ALGO

# %%
df = pd.read_csv('appliance_energy.csv')

# %%
df
# Out:
#     Temperature (°C)  Energy Consumption (kWh)
# 0          22.490802                  2.292604
# 1          34.014286                  3.251925
# 2          29.639879                  3.009868
# 3          26.973170                  1.703533
# 4          18.120373                  1.702201
# ..               ...                       ...
# 95         24.875912                  2.079686
# 96         25.454657                  2.506915
# 97         23.550820                  2.525658
# 98         15.508383                  1.689184
# 99         17.157829                  2.129374
#
# [100 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Temperature (°C)          100 non-null    float64
#  1   Energy Consumption (kWh)  100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
df.describe()
# Out:
#        Temperature (°C)  Energy Consumption (kWh)
# count        100.000000                100.000000
# mean          24.403615                  2.439821
# std            5.949788                  0.693527
# min           15.110442                  0.978107
# 25%           18.864015                  1.908640
# 50%           24.282849                  2.364121
# 75%           29.604062                  2.931199
# max           34.737739                  4.159094

# %%
df.dtypes
# Out:
# Temperature (°C)            float64
# Energy Consumption (kWh)    float64
# dtype: object

# %%
df.isna()
# Out:
#     Temperature (°C)  Energy Consumption (kWh)
# 0              False                     False
# 1              False                     False
# 2              False                     False
# 3              False                     False
# 4              False                     False
# ..               ...                       ...
# 95             False                     False
# 96             False                     False
# 97             False                     False
# 98             False                     False
# 99             False                     False
#
# [100 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# Temperature (°C)            0
# Energy Consumption (kWh)    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
sns.pairplot(df)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.pie(df['Energy Consumption (kWh)'].value_counts(),labels=df['Energy Consumption (kWh)'].unique(),autopct='%1.1f%%')
plt.title('Energy Consumption Distribution')
plt.show()

# %%
plt.bar(df['Temperature (°C)'],df['Energy Consumption (kWh)'])
plt.title('Energy Consumption vs Temperature')
plt.ylabel('Energy Consumption (kWh)')
plt.xlabel('Temperature (°C)')
plt.show()

# %%
plt.hist(df['Temperature (°C)'],bins=10)
plt.title('Temperature Distribution')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(df['Temperature (°C)'])
plt.title('Temperature Boxplot')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
plt.scatter(df['Temperature (°C)'],df['Energy Consumption (kWh)'])
plt.title('Energy Consumption vs Temperature')
plt.ylabel('Energy Consumption (kWh)')
plt.xlabel('Temperature (°C)')
plt.show()

# %%
x= df[['Temperature (°C)']]
y= df[['Energy Consumption (kWh)']]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#     Temperature (°C)
# 55         33.437485
# 88         32.744255
# 26         18.993476
# 42         15.687770
# 69         34.737739
# ..               ...
# 60         22.773546
# 71         18.974314
# 14         18.636499
# 92         30.215701
# 51         30.502656
#
# [80 rows x 1 columns]

# %%
y_train
# Out:
#     Energy Consumption (kWh)
# 55                  3.378030
# 88                  3.756114
# 26                  1.727990
# 42                  2.140188
# 69                  3.864685
# ..                       ...
# 60                  1.885728
# 71                  1.237203
# 14                  1.912189
# 92                  2.898876
# 51                  2.767117
#
# [80 rows x 1 columns]

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([[1.6858187 ],
#        [3.18154068],
#        [2.96097494],
#        [2.76354868],
#        [2.0370856 ],
#        [2.36343345],
#        [2.09711944],
#        [3.12445907],
#        [1.60849483],
#        [2.24537556],
#        [2.34866555],
#        [2.66462648],
#        [3.0387357 ],
#        [3.27880886],
#        [1.78664542],
#        [1.85218469],
#        [2.95922164],
#        [1.70468695],
#        [3.0692904 ],
#        [1.87828475]])

# %%
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test,y_pred)
print("MEAN SQUARE ERROR:",mse)
print("ACCURACY:",mse*100)
# Out:
# MEAN SQUARE ERROR: 0.16342487842925055
# ACCURACY: 16.342487842925056

# %%
y_pred = model.predict(x_test)
r2 = r2_score(y_test,y_pred)
print("R2 SCORE:",r2)
# Out:
# R2 SCORE: 0.6119478445218713

# %%
print("ROOT MEAN SQUARE ERROR:",np.sqrt(mse))
# Out:
# ROOT MEAN SQUARE ERROR: 0.40425843025130664

# %% [markdown]
# > random stated is applied to freez the dataset and to get the same accuracy every time

# %%
m = model.coef_
print("SLOPE:",m)
# Out:
# SLOPE: [[0.08996618]]

# %%
c = model.intercept_
print("INTERCEPT:",c)
# Out:
# INTERCEPT: [0.22196392]

# %%
plt.scatter(x_test,y_test,label='TEST DATA')
plt.plot(x_test,y_pred,color='red',label='PREDICTION or BEST FITTED LINE or REGRESSION LINE')
plt.xlabel('Temperature (°C)')
plt.ylabel('Energy Consumption (kWh)')
plt.legend()
plt.title('Temperature vs Energy Consumption (TEST DATA)')
plt.show()

# %%
plt.scatter(df['Temperature (°C)'],df['Energy Consumption (kWh)'],label='TEST DATA')
plt.plot(x_test,y_pred,color='red',label='PREDICTION or BEST FITTED LINE or REGRESSION LINE')
plt.xlabel('Temperature (°C)')
plt.ylabel('Energy Consumption (kWh)')
plt.legend()
plt.title('Temperature vs Energy Consumption (ENTIRE DATA)')
plt.show()

# %%
plt.scatter(x_train,y_train,label='TEST DATA')
plt.plot(x_test,y_pred,color='red',label='PREDICTION or BEST FITTED LINE or REGRESSION LINE')
plt.xlabel('Temperature (°C)')
plt.ylabel('Energy Consumption (kWh)')
plt.legend()
plt.title('Temperature vs Energy Consumption (TRAIN DATA)')
plt.show()

# %%
import joblib
joblib.dump(model,'energy_consumption_model.joblib') #WE CAN EITHER USE .PKL OR .JOBLIB
# Out:
# ['energy_consumption_model.joblib']

# %% [markdown]
# > IF WE WANT TO SHARE JUST THE PRE-TRAINED MODEL WE CAN SHRE IT WITH PKL OR JOBLIB FILE (SERIALIZATION) AND OPPOSITE PROCESS IS (DESERIALIZATION)

# %%
model.predict([[24]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.38115231]])
