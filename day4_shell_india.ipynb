# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmay023/GREEN-SKILL-AND-AI/blob/main/day4_shell_india.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from matplotlib.lines import lineStyles
months = ['Jan','Feb','Mar','Apr','May','Jun']
energy_consumption = [1200,1300,1100,1500,1400,1600]

plt.plot(months,energy_consumption,marker= 'D',color='g',linestyle='--',ms=10,mec='k',mfc='m') # used to draw points (MARKERS) draws line from point to point (x-label,y-label)
plt.title("Energy Consumption")
plt.xlabel("Months")
plt.ylabel("Energy Consumption (MWh)")
plt.show()

# %%
energy_sources = ['Solar','Wind','Hydropower','Biomass']
energy_value = [1200,1400,2900,2500]

plt.bar(energy_sources,energy_value,color='green')
plt.title("Energy Consumption")
plt.xlabel("Energy Sources")
plt.ylabel("Energy Consumption (MWh)")
plt.grid()
plt.show()

# %%
plt.barh(energy_sources,energy_value,color='green')
plt.title("Energy Consumption")
plt.xlabel("Energy Sources")
plt.ylabel("Energy Consumption (MWh)")
plt.grid()
plt.show()

# %%
from IPython.core.magics import auto
plt.pie(energy_value,labels=energy_sources,autopct='%1.1f%%',startangle=90)

plt.title('Energy Consumption by source')
plt.show()

# %%
carbon_emission = [200,500,450,300]
plt.scatter(energy_value,carbon_emission,color='b')

plt.title('Energy Consumption vs Carbon Emission')
plt.xlabel('Energy Consumption (MWh)')
plt.ylabel('Carbon Emission (kg co2)')
plt.show()

# %%
plt.bar(energy_sources,energy_value,edgecolor='b',color='g')
plt.title("Customisez energy consumption by source",fontsize=15,fontweight='bold')
plt.ylabel("Energy Consumption (MWh)",fontsize=12)
plt.xlabel("Energy Sources",fontsize=12)

plt.grid(True)
plt.legend(['energy_consumption'],loc='upper left')
plt.show()

# %%
data = {
    "Solar" :[1500,2000,3000],
    "Wind":[1400,1600,1100],
    "Hydropower":[1200,700,1100],
    "Biomass":[1700,800,900]
}

# %%
data.keys()
# Out:
# dict_values([[1500, 2000, 3000], [1400, 1600, 1100], [1200, 700, 1100], [1700, 800, 900]])

# %%
data.values()
# Out:
# dict_values([[1500, 2000, 3000], [1400, 1600, 1100], [1200, 700, 1100], [1700, 800, 900]])

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    Solar  Wind  Hydropower  Biomass
# 0   1500  1400        1200     1700
# 1   2000  1600         700      800
# 2   3000  1100        1100      900

# %%
plt.boxplot(df) # ploted form pandas directly
plt.show()

# %%
import seaborn as sns

sns.boxplot(df) #ploted from seaborn
plt.show()

# %%
df.describe()
# Out:
#              Solar         Wind   Hydropower      Biomass
# count     3.000000     3.000000     3.000000     3.000000
# mean   2166.666667  1366.666667  1000.000000  1133.333333
# std     763.762616   251.661148   264.575131   493.288286
# min    1500.000000  1100.000000   700.000000   800.000000
# 25%    1750.000000  1250.000000   900.000000   850.000000
# 50%    2000.000000  1400.000000  1100.000000   900.000000
# 75%    2500.000000  1500.000000  1150.000000  1300.000000
# max    3000.000000  1600.000000  1200.000000  1700.000000

# %% [markdown]
# IQR (INTER QURTALIE RANGE)

# %% [markdown]
# Q1 - 25
# Q2 - 50
# Q3 - 75

# %%
sns.displot([0, 1, 2, 3, 4, 5])

plt.show()

# %%
sns.displot([0, 1, 2, 3, 4, 5], kind="kde")

plt.show()

# %%
data = {
    "Solar" :[1500,2000,3000],
    "Wind":[1400,1600,1100],
    "Hydropower":[1200,700,1100],
    "Biomass":[1700,800,900]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Solar  Wind  Hydropower  Biomass
# 0   1500  1400        1200     1700
# 1   2000  1600         700      800
# 2   3000  1100        1100      900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Solar       3 non-null      int64
#  1   Wind        3 non-null      int64
#  2   Hydropower  3 non-null      int64
#  3   Biomass     3 non-null      int64
# dtypes: int64(4)
# memory usage: 228.0 bytes

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# EDA

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# pair plot and heatmaps used for feature selection

# %%
sns.boxplot(df)
plt.title("BOX PLOT OF THE DATASET")
plt.show()

# %%
sns.violinplot(df)
plt.title("VIOLIN PLOT OF THE DATASET")
plt.show()
