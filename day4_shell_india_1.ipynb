# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmay023/GREEN-SKILL-AND-AI/blob/main/day4_shell_india_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MACHINE LEARNING

# %% [markdown]
# > INTRODUCTION
#
# 1. CREATING SYSTEM WORK LIKE HUMANS
#
# 2. TYPES OF AI
# - NARROW AI (VERY SPECIFIC ACTION)
# - ARTIFICIAL GENERAL INTELLIGENCE (DESIGNED TO LEARN THINK AND PERFORM SIMILAR TASK)
# - ARTIFICIAL SUPERINTELLIGENCE (EG. SOPHIA)
#
# -- CONCEPTS
#
# ML,DL
# NLP (WORKS ON TEXT DATA)
# COMPUTER VISION (IMAGE DATA)
# REINFORCEMENT LEARNING
# GENERATIVE MODELS (EG. GPT)
# EXPLAINABLE AI (EG. DEEPSEEK TINKING MODEL)
#
# AL ML INPORTANCE OF SUSTAINABILITY
#
# - OPTIMIZING ENERGY CONSUMPTION
#  -- SMART GRID
#  -- NERGY EFFICIENCY
#  -- RENEWABLE ENERGY
#
# - IMPROVING AGRICULTURE DOMAIN
#  -- PRECISION AGRICULTURE
#  -- YIELD PREDICTION
#  -- SUSTAINABLE FARMING
#
# - SUPPORTING CLIMATE CHANGE MITIGATION
#  -- CLIMATE MODELING
#  -- CARBON FOOTPRINT REDUCTION
#  -- DISASTER MANAGEMENT
#
# - ENHANCING RESOURCE MANAGEMENT
#  -- WATER MANAGEMENT
#  -- WASTE REDUCTION
#  -- SUSTAINABLE SUPPLY CHAINS
#
#  - SUSTAINABLE URBAN DEVELOPMENT
#  - ENVIRONMENTAL DEVELOPMENT

# %% [markdown]
# > SUPERVISED ML
#
# ML - LIKE TEACHING A BABY
#
# SML: TRAINING MACHINE USING I\P AND O\P.

# %% [markdown]
# > UNSUPERVISED ML

# %%
- USML: ONLY I\P O\P - BASED ON

# %% [markdown]
# > REINFORCEMENT LEARNING
#
# -- AGENT

# %% [markdown]
# 1. DEFINE A PROBLEM
# 2. COLLECT AN DPREPARE A DATA
# 3. SPLITING (TRAINING AND TESTING)
# 4. DEVELOP ML MODEL
# 5. TEST AND REFINE ML MODEL
# 6. DEPLOY AND MAINTAIN
# 7. MANAGE PREDICTIVE SERVICE

# %% [markdown]
# supervised learning algorithm
# 1. regression algorithm (weather prediction,energyconsumption,medical cost)
#  -- works on type of continious type of o\p
#   --
#     1. linear regression
#     2. polynomial regresssion
#
#
# 2. classification algorithm
#  -- works on discrete type of o\p
#   --
#     1. logistic
#     2. decision trees
#     3. random forest
#     4. svm
#     5. k-nearest neighbors (k-nn)
#     6. naive bayes
